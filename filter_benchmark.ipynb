# %% [markdown]
# ### Steric filter benchmark
#
# In this interactive notebook, the results of the steric filter benchmark are summarized from `filter_benchmark.ipynb`. These steric rules are derived from a benchmark of theoretical structures. In this benchmark, each substructure class was iterated over with an increasing number of tert-butyl groups as the substituents around the rotatable axis (starting from zero, i.e. all hydrogens) and the rotational barrier computed using the atropisomers workflow with the methods and levels of theory described in the manuscript. The rotational barriers computed by our workflow were then used to infer the maximum allowed number of non-heavy substituents per substructure, using 12 kcal/mol as a conservative threshold. Note that some entries are skipped, but were not needed to define the rules.
#
# #### Imports

# %%
import pandas as pd
from rdkit.Chem import AllChem as Chem
from rdkit.Chem import Draw

# %% [markdown]
# #### Results

# %%
# Load the .csv file as a dataframe
df = pd.read_csv('filter_benchmark.csv')

# %%
# Iterate over each row of the dataframe
for index, row in df.iterrows():

    # Create an RDKit molecule from the SMILES string
    mol = Chem.MolFromSmiles(row['SMILES'])
    
    # Display the molecule
    display(Draw.MolToImage(mol))

    # Print the results
    print(f"{row['Index']}. SMILES: {row['SMILES']}")
    print(f"Computed barrier: {row['Computed barrier (kcal/mol)']} (class {row['Computed class']})")

    # Determine if the barrier meets the threshold for scanning
    if row['Computed barrier (kcal/mol)'] > 12:
        print("Barrier meets scan threshold\n")
    else:
        print("Barrier fails scan threshold\n")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 1. SMILES: CC(C)(C)c1ccC(=O)cc(C(C)(C)C)c1-c1c(C(C)(C)C)cccc1C(C)(C)C
# Computed barrier: 68.59 (class 3)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 2. SMILES: c1ccC(=O)cc(C(C)(C)C)c1-c1c(C(C)(C)C)cccc1C(C)(C)C
# Computed barrier: 51.12 (class 3)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 3. SMILES: c1ccC(=O)cc(C(C)(C)C)c1-c1c(C(C)(C)C)cccc1
# Computed barrier: 24.35 (class 2)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 4. SMILES: CC(C)(C)c1ccC(=O)cc(C(C)(C)C)c1-c1ccccc1
# Computed barrier: 13.72 (class 1)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 5. SMILES: c1ccC(=O)ccc1-c1c(C(C)(C)C)cccc1C(C)(C)C
# Computed barrier: 26.31 (class 2)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 6. SMILES: CC(C)(C)c1ccC(=O)ccc1-c1ccccc1
# Computed barrier: 18.35 (class 1)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 7. SMILES: c1ccC(=O)ccc1-c1ccccc1C(C)(C)C
# Computed barrier: 19.41 (class 1)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 8. SMILES: c1ccC(=O)ccc1-c1ccccc1
# Computed barrier: 4.35 (class 1)
# Barrier fails scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 9. SMILES: CC(C)(C)c1cccc(C(C)(C)C)c1-c1c(C(C)(C)C)cccc1C(C)(C)C
# Computed barrier: 116.91 (class 3)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 10. SMILES: CC(C)(C)c1ccccc1-c1c(C(C)(C)C)cccc1C(C)(C)C
# Computed barrier: 61.9 (class 3)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 11. SMILES: CC(C)(C)c1ccccc1-c1ccccc1C(C)(C)C
# Computed barrier: 37.46 (class 3)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 12. SMILES: c1ccccc1-c1c(C(C)(C)C)cccc1C(C)(C)C
# Computed barrier: 26.5 (class 2)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 13. SMILES: c1ccccc1-c1ccccc1C(C)(C)C
# Computed barrier: 15.61 (class 1)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 14. SMILES: CC(C)(C)c1cccc(C(C)(C)C)c1-c1c(C(C)(C)C)coc1C(C)(C)C
# Computed barrier: 73.84 (class 3)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 15. SMILES: CC(C)(C)c1ccccc1-c1c(C(C)(C)C)coc1C(C)(C)C
# Computed barrier: 63.42 (class 3)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 16. SMILES: CC(C)(C)c1ccccc1-c1ccoc1C(C)(C)C
# Computed barrier: 21.42 (class 2)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 17. SMILES: c1cocc1-c1c(C(C)(C)C)cccc1C(C)(C)C
# Computed barrier: 22.15 (class 2)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 18. SMILES: c1ccccc1-c1c(C(C)(C)C)coc1C(C)(C)C
# Computed barrier: 19.19 (class 1)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 19. SMILES: c1cocc1-c1ccccc1C(C)(C)C
# Computed barrier: 6.8 (class 1)
# Barrier fails scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 20. SMILES: c1ccccc1-c1ccoc1C(C)(C)C
# Computed barrier: 5.9 (class 1)
# Barrier fails scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 21. SMILES: CC(C)(C)c1coc(C(C)(C)C)c1-c1c(C(C)(C)C)coc1C(C)(C)C
# Computed barrier: 83.58 (class 3)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 22. SMILES: CC(C)(C)c1cocc1-c1c(C(C)(C)C)coc1C(C)(C)C
# Computed barrier: 48.32 (class 3)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 23. SMILES: CC(C)(C)c1cocc1-c1ccoc1C(C)(C)C
# Computed barrier: 12.55 (class 1)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 24. SMILES: c1cocc1-c1c(C(C)(C)C)coc1C(C)(C)C
# Computed barrier: 11.85 (class 1)
# Barrier fails scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 25. SMILES: CC(C)(C)c1cccc(C(C)(C)C)c1Oc1c(C(C)(C)C)cccc1C(C)(C)C
# Computed barrier: 51.14 (class 3)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 26. SMILES: CC(C)(C)c1ccccc1Oc1c(C(C)(C)C)cccc1C(C)(C)C
# Computed barrier: 35.01 (class 3)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 27. SMILES: CC(C)(C)c1ccccc1Oc1ccccc1C(C)(C)C
# Computed barrier: 24.66 (class 2)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 28. SMILES: c1ccccc1Oc1c(C(C)(C)C)cccc1C(C)(C)C
# Computed barrier: 16.49 (class 1)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 29. SMILES: c1ccccc1Oc1ccccc1C(C)(C)C
# Computed barrier: 8.64 (class 1)
# Barrier fails scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 30. SMILES: CC(C)(C)c1ccccc1Oc1c(C(C)(C)C)coc1C(C)(C)C
# Computed barrier: 31.27 (class 3)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 31. SMILES: CC(C)(C)c1ccccc1Oc1ccoc1C(C)(C)C
# Computed barrier: 11.97 (class 1)
# Barrier fails scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 32. SMILES: c1cocc1Oc1c(C(C)(C)C)cccc1C(C)(C)C
# Computed barrier: 12.0 (class 1)
# Barrier fails scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 33. SMILES: c1ccccc1Oc1c(C(C)(C)C)coc1C(C)(C)C
# Computed barrier: 13.75 (class 1)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 34. SMILES: CC(C)(C)c1coc(C(C)(C)C)c1Oc1c(C(C)(C)C)coc1C(C)(C)C
# Computed barrier: 48.58 (class 3)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 35. SMILES: CC(C)(C)c1cocc1Oc1c(C(C)(C)C)coc1C(C)(C)C
# Computed barrier: 25.36 (class 2)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 36. SMILES: CC(C)(C)c1cocc1Oc1ccoc1C(C)(C)C
# Computed barrier: 5.33 (class 1)
# Barrier fails scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 37. SMILES: c1cocc1Oc1c(C(C)(C)C)coc1C(C)(C)C
# Computed barrier: 9.65 (class 1)
# Barrier fails scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 38. SMILES: CC(C)(C)c1cccc(C(C)(C)C)c1Sc1c(C(C)(C)C)cccc1C(C)(C)C
# Computed barrier: 28.81 (class 2)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 39. SMILES: CC(C)(C)c1ccccc1Sc1c(C(C)(C)C)cccc1C(C)(C)C
# Computed barrier: 21.92 (class 2)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 40. SMILES: CC(C)(C)c1ccccc1Sc1ccccc1C(C)(C)C
# Computed barrier: 14.73 (class 1)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 41. SMILES: c1ccccc1Sc1c(C(C)(C)C)cccc1C(C)(C)C
# Computed barrier: 13.08 (class 1)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 42. SMILES: CC(C)(C)c1cccc(C(C)(C)C)c1Sc1c(C(C)(C)C)coc1C(C)(C)C
# Computed barrier: 25.02 (class 2)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 43. SMILES: CC(C)(C)c1ccccc1Sc1c(C(C)(C)C)coc1C(C)(C)C
# Computed barrier: 20.73 (class 2)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 44. SMILES: CC(C)(C)c1ccccc1Sc1ccoc1C(C)(C)C
# Computed barrier: 7.57 (class 1)
# Barrier fails scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 45. SMILES: c1cocc1Sc1c(C(C)(C)C)cccc1C(C)(C)C
# Computed barrier: 7.87 (class 1)
# Barrier fails scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 46. SMILES: c1ccccc1Sc1c(C(C)(C)C)coc1C(C)(C)C
# Computed barrier: 9.66 (class 1)
# Barrier fails scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 47. SMILES: CC(C)(C)c1coc(C(C)(C)C)c1Sc1c(C(C)(C)C)coc1C(C)(C)C
# Computed barrier: 27.06 (class 2)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 48. SMILES: CC(C)(C)c1cocc1Sc1c(C(C)(C)C)coc1C(C)(C)C
# Computed barrier: 16.17 (class 1)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 49. SMILES: CC(C)(C)c1cocc1Sc1ccoc1C(C)(C)C
# Computed barrier: 5.15 (class 1)
# Barrier fails scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 50. SMILES: c1cocc1Sc1c(C(C)(C)C)coc1C(C)(C)C
# Computed barrier: 5.22 (class 1)
# Barrier fails scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 51. SMILES: CC(C)(C)c1ccccc1N(C(C)(C)C)c1c(C(C)(C)C)cccc1C(C)(C)C
# Computed barrier: 28.71 (class 2)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 52. SMILES: CC(C)(C)c1ccccc1N(C(C)(C)C)c1ccccc1C(C)(C)C
# Computed barrier: 16.07 (class 1)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 53. SMILES: c1ccccc1N(C(C)(C)C)c1c(C(C)(C)C)cccc1C(C)(C)C
# Computed barrier: 27.35 (class 2)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 54. SMILES: c1ccccc1N(C(C)(C)C)c1c(C(C)(C)C)cccc1
# Computed barrier: 8.34 (class 1)
# Barrier fails scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 55. SMILES: CC(C)(C)c1ccccc1N(C(C)(C)C)c1c(C(C)(C)C)coc1C(C)(C)C
# Computed barrier: 15.14 (class 1)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 56. SMILES: c1cocc1N(C(C)(C)C)c1c(C(C)(C)C)cccc1C(C)(C)C
# Computed barrier: 16.97 (class 1)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 57. SMILES: c1ccccc1N(C(C)(C)C)c1c(C(C)(C)C)coc1C(C)(C)C
# Computed barrier: 12.78 (class 1)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 58. SMILES: c1cocc1N(C(C)(C)C)c1c(C(C)(C)C)cccc1
# Computed barrier: 5.19 (class 1)
# Barrier fails scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 59. SMILES: c1ccccc1N(C(C)(C)C)c1ccoc1C(C)(C)C
# Computed barrier: 4.67 (class 1)
# Barrier fails scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 60. SMILES: CC(C)(C)c1coc(C(C)(C)C)c1N(C(C)(C)C)c1c(C(C)(C)C)coc1C(C)(C)C
# Computed barrier: 27.35 (class 2)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 61. SMILES: CC(C)(C)c1cocc1N(C(C)(C)C)c1c(C(C)(C)C)coc1C(C)(C)C
# Computed barrier: 15.4 (class 1)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 62. SMILES: c1cocc1N(C(C)(C)C)c1c(C(C)(C)C)coc1C(C)(C)C
# Computed barrier: 9.86 (class 1)
# Barrier fails scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 63. SMILES: CC(C)(C)N(C(C)(C)C)C(=O)c1c(C(C)(C)C)cccc1C(C)(C)C
# Computed barrier: 23.79 (class 2)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 64. SMILES: CC(C)(C)N(C(C)(C)C)C(=O)c1ccccc1C(C)(C)C
# Computed barrier: 4.98 (class 1)
# Barrier fails scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 65. SMILES: CC(C)(C)N(C(C)(C)C)C(=O)c1c(C(C)(C)C)coc1C(C)(C)C
# Computed barrier: 10.91 (class 1)
# Barrier fails scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 66. SMILES: CC(C)(C)N(C(C)(C)C)C(=O)c1cocc1C(C)(C)C
# Computed barrier: 9.24 (class 1)
# Barrier fails scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 67. SMILES: CC(C)(C)N(C(C)(C)C)C(=S)c1ccccc1C(C)(C)C
# Computed barrier: 9.91 (class 1)
# Barrier fails scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 68. SMILES: CC(C)(C)N(C(C)(C)C)C(=S)c1ccccc1
# Computed barrier: 14.73 (class 1)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 69. SMILES: CC(C)(C)N(C(C)(C)C)C(=S)c1c(C(C)(C)C)coc1C(C)(C)C
# Computed barrier: 18.73 (class 1)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 70. SMILES: CC(C)(C)N(C(C)(C)C)C(=S)c1cocc1C(C)(C)C
# Computed barrier: 14.92 (class 1)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 71. SMILES: CC(C)(C)c1cccc(C(C)(C)C)c1N(C(C)(C)C)C(C(C)(C)C)=O
# Computed barrier: 55.16 (class 3)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 72. SMILES: c1coc(C(C)(C)C)c1N(C(C)(C)C)C(C(C)(C)C)=O
# Computed barrier: 33.35 (class 3)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 73. SMILES: CC(C)(C)c1cccc(C(C)(C)C)c1N(C(C)(C)C)C(C(C)(C)C)=S
# Computed barrier: 52.31 (class 3)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 74. SMILES: c1coc(C(C)(C)C)c1N(C(C)(C)C)C(C(C)(C)C)=S
# Computed barrier: 30.02 (class 3)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 75. SMILES: CC(C)(C)c1ccccc1S(=O)C(C)(C)(C)
# Computed barrier: 10.69 (class 1)
# Barrier fails scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 76. SMILES: CC(C)(C)c1coc(C(C)(C)C)c1S(=O)C(C)(C)(C)
# Computed barrier: 19.21 (class 1)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 77. SMILES: CC(C)(C)c1cocc1S(=O)C(C)(C)(C)
# Computed barrier: 4.46 (class 1)
# Barrier fails scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 78. SMILES: CC(C)(C)c1ccccc1S(=O)(=O)C(C)(C)(C)
# Computed barrier: 7.83 (class 1)
# Barrier fails scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 79. SMILES: CC(C)(C)c1coc(C(C)(C)C)c1S(=O)(=O)C(C)(C)(C)
# Computed barrier: 18.44 (class 1)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 80. SMILES: CC(C)(C)c1cocc1S(=O)(=O)C(C)(C)(C)
# Computed barrier: 5.55 (class 1)
# Barrier fails scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 81. SMILES: CC(C)(C)N(C(C)(C)C)C(=O)C(C)(C)C
# Computed barrier: 19.39 (class 1)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 82. SMILES: N(C(C)(C)C)C(=O)C(C)(C)C
# Computed barrier: 19.06 (class 1)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 83. SMILES: CC(C)(C)N(C(C)(C)C)C(=O)
# Computed barrier: 13.9 (class 1)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 84. SMILES: NC(=O)C(C)(C)C
# Computed barrier: 15.02 (class 1)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 85. SMILES: NC(=O)C
# Computed barrier: 16.36 (class 1)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 86. SMILES: CC(C)(C)N(C(C)(C)C)C(=S)C(C)(C)C
# Computed barrier: 28.47 (class 2)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 87. SMILES: N(C(C)(C)C)C(=S)C(C)(C)C
# Computed barrier: 21.39 (class 2)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 88. SMILES: CC(C)(C)N(C(C)(C)C)C(=S)
# Computed barrier: 17.01 (class 1)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 89. SMILES: N(C(C)(C)C)C(=S)
# Computed barrier: 24.93 (class 2)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 90. SMILES: NC(=S)C(C)(C)C
# Computed barrier: 18.32 (class 1)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 91. SMILES: NC(=S)C
# Computed barrier: 19.43 (class 1)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 92. SMILES: CC(C)(C)C1CCCC(C(C)(C)C)C(C(C)(C)C)1c2ccccc2
# Computed barrier: 22.91 (class 2)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 93. SMILES: C1CCCC(C(C)(C)C)C(C(C)(C)C)1c2c(C(C)(C)C)cccc2
# Computed barrier: 43.73 (class 3)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 94. SMILES: C1CCC(C(C)(C)C)C(C(C)(C)C)1c2c(C(C)(C)C)cccc2C(C)(C)C
# Computed barrier: 15.99 (class 1)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 95. SMILES: CC(C)(C)C1CCC(C(C)(C)C)C(C(C)(C)C)1c2c(C(C)(C)C)cccc2
# Computed barrier: 36.45 (class 3)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 96. SMILES: C1CCCC(C(C)(C)C)1c2c(C(C)(C)C)cccc2C(C)(C)C
# Computed barrier: 27.09 (class 2)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 97. SMILES: CC(C)(C)C1CCC(C(C)(C)C)C(C(C)(C)C)1c2ccccc2
# Computed barrier: 15.05 (class 1)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 98. SMILES: C1CCC(C(C)(C)C)C(C(C)(C)C)1c2c(C(C)(C)C)cccc2
# Computed barrier: 20.63 (class 2)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 99. SMILES: CC(C)(C)C1CCCC(C(C)(C)C)C(C(C)(C)C)1c2c(C(C)(C)C)coc2C(C)(C)C
# Computed barrier: 66.49 (class 3)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 100. SMILES: CC(C)(C)C1CCCC(C(C)(C)C)C(C(C)(C)C)1c2c(C(C)(C)C)coc2
# Computed barrier: 49.66 (class 3)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 101. SMILES: C1CCCCC(C(C)(C)C)1c2c(C(C)(C)C)coc2C(C)(C)C
# Computed barrier: 20.86 (class 2)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 102. SMILES: CC(C)(C)C1CCCC(C(C)(C)C)C(C(C)(C)C)1c2ccoc2
# Computed barrier: 10.19 (class 1)
# Barrier fails scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 103. SMILES: C1CCCC(C(C)(C)C)C(C(C)(C)C)1c2c(C(C)(C)C)coc2
# Computed barrier: 12.07 (class 1)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 104. SMILES: CC(C)(C)C1CCC(C(C)(C)C)C(C(C)(C)C)1c2c(C(C)(C)C)coc2C(C)(C)C
# Computed barrier: 39.39 (class 3)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 105. SMILES: C1CCC(C(C)(C)C)C(C(C)(C)C)1c2c(C(C)(C)C)coc2C(C)(C)C
# Computed barrier: 33.81 (class 3)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 106. SMILES: CC(C)(C)C1CCC(C(C)(C)C)C(C(C)(C)C)1c2c(C(C)(C)C)coc2
# Computed barrier: 19.74 (class 1)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 107. SMILES: C1CCCC(C(C)(C)C)1c2c(C(C)(C)C)coc2C(C)(C)C
# Computed barrier: 17.27 (class 1)
# Barrier meets scan threshold
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=300x300>
# 108. SMILES: CC(C)(C)C1CCC(C(C)(C)C)C(C(C)(C)C)1c2ccoc2
# Computed barrier: 18.34 (class 1)
# Barrier meets scan threshold
